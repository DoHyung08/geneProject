# %% [markdown]
# ### train

# %%
modelName = "MultiAlle"

# %%
from stable_baselines3.common.env_checker import check_env
from geneEnv import geneEnv
from ratioEnv import ratioEnv
from flockEnv import flockEnv
from pig import pig



with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
# 읽어온 코드 실행
exec(code)


env = geneEnv(1,32,10)
# It will check your custom environment and output additional warnings if needed
check_env(env)
# Out:
# Gene Environment setting success

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor
from geneEnv import geneEnv



env = geneEnv(1,32,10)
env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

# print(f"Observation space: {env.observation_space}")
# print(f"Action space: {env.action_space}")
# print(f"Sample observation: {env.reset()}")

model = PPO("MlpPolicy", env, verbose=1,n_epochs=30)
model.learn(total_timesteps=800_000)
model.save("result\\"+modelName+"\\trained_model")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    fps             | 62       |
# |    iterations      | 1        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 2           |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.045029707 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | -0.000891   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.157      |
# |    value_loss           | 6.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 3           |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.058857225 |
# |    clip_fraction        | 0.867       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 6.74e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.88e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.158      |
# |    value_loss           | 5.01e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 166        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 4          |
# |    time_elapsed         | 221        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.08666927 |
# |    clip_fraction        | 0.889      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 3.81e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.48e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.159     |
# |    value_loss           | 3.94e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 166       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 5         |
# |    time_elapsed         | 282       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 1.2878904 |
# |    clip_fraction        | 0.905     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -111      |
# |    explained_variance   | 3.28e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.68e+03  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -0.155    |
# |    value_loss           | 3.41e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 176       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 6         |
# |    time_elapsed         | 340       |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0662666 |
# |    clip_fraction        | 0.887     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -111      |
# |    explained_variance   | 0.25      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.26e+03  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -0.157    |
# |    value_loss           | 2.73e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 7          |
# |    time_elapsed         | 399        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.06152696 |
# |    clip_fraction        | 0.873      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.277      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.36e+03   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.155     |
# |    value_loss           | 2.6e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 8           |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.059418425 |
# |    clip_fraction        | 0.864       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.154      |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 172        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 9          |
# |    time_elapsed         | 525        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.05564154 |
# |    clip_fraction        | 0.862      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.32       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05e+03   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.152     |
# |    value_loss           | 2.5e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 10          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.049429208 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 11          |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.049768955 |
# |    clip_fraction        | 0.84        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 172         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 12          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.048206724 |
# |    clip_fraction        | 0.826       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.37e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 175        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 13         |
# |    time_elapsed         | 757        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.04672162 |
# |    clip_fraction        | 0.826      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05e+03   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.19e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 176        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 14         |
# |    time_elapsed         | 817        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.04437682 |
# |    clip_fraction        | 0.825      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.296      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12e+03   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.41e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 15          |
# |    time_elapsed         | 875         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.045758724 |
# |    clip_fraction        | 0.832       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 804         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 16          |
# |    time_elapsed         | 931         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.042668212 |
# |    clip_fraction        | 0.806       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 915         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.18e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 156        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 17         |
# |    time_elapsed         | 988        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.04208572 |
# |    clip_fraction        | 0.813      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.33       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 987        |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.22e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 178        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 18         |
# |    time_elapsed         | 1043       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.04118874 |
# |    clip_fraction        | 0.8        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.352      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 862        |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 2.13e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 172        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 19         |
# |    time_elapsed         | 1100       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03982732 |
# |    clip_fraction        | 0.805      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.307      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18e+03   |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.31e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 172         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 20          |
# |    time_elapsed         | 1157        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.038444754 |
# |    clip_fraction        | 0.802       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 162        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 21         |
# |    time_elapsed         | 1216       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03915693 |
# |    clip_fraction        | 0.792      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.326      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 750        |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.148     |
# |    value_loss           | 2.24e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 172         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 22          |
# |    time_elapsed         | 1274        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.038317688 |
# |    clip_fraction        | 0.781       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+03    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 23          |
# |    time_elapsed         | 1333        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.037618324 |
# |    clip_fraction        | 0.792       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 782         |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.25e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 169        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 24         |
# |    time_elapsed         | 1389       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03704126 |
# |    clip_fraction        | 0.784      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.292      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 793        |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.148     |
# |    value_loss           | 2.4e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 25         |
# |    time_elapsed         | 1445       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03580233 |
# |    clip_fraction        | 0.778      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 824        |
# |    n_updates            | 720        |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 2.24e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 26          |
# |    time_elapsed         | 1501        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.036735583 |
# |    clip_fraction        | 0.784       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 961         |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 185         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 27          |
# |    time_elapsed         | 1558        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.036140013 |
# |    clip_fraction        | 0.775       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 28          |
# |    time_elapsed         | 1613        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.035259694 |
# |    clip_fraction        | 0.78        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 854         |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 29          |
# |    time_elapsed         | 1670        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.033552997 |
# |    clip_fraction        | 0.751       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 630         |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 30          |
# |    time_elapsed         | 1727        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.034075096 |
# |    clip_fraction        | 0.755       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 181        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 31         |
# |    time_elapsed         | 1783       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03510563 |
# |    clip_fraction        | 0.774      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.246      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.28e+03   |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.45e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 32          |
# |    time_elapsed         | 1840        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.033890314 |
# |    clip_fraction        | 0.768       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 33          |
# |    time_elapsed         | 1897        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.034337692 |
# |    clip_fraction        | 0.765       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 611         |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.147      |
# |    value_loss           | 2.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 34          |
# |    time_elapsed         | 1953        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.034140367 |
# |    clip_fraction        | 0.769       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 901         |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 35          |
# |    time_elapsed         | 2010        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.034487724 |
# |    clip_fraction        | 0.759       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+03    |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 178        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 36         |
# |    time_elapsed         | 2066       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03378267 |
# |    clip_fraction        | 0.75       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.327      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.11e+03   |
# |    n_updates            | 1050       |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 2.17e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 37          |
# |    time_elapsed         | 2121        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.033768963 |
# |    clip_fraction        | 0.755       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 38         |
# |    time_elapsed         | 2176       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.03280773 |
# |    clip_fraction        | 0.746      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.267      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.01e+03   |
# |    n_updates            | 1110       |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 2.13e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 168        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 39         |
# |    time_elapsed         | 2233       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03317867 |
# |    clip_fraction        | 0.746      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.302      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 932        |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 2.08e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 182        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 40         |
# |    time_elapsed         | 2293       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03214477 |
# |    clip_fraction        | 0.734      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.249      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 877        |
# |    n_updates            | 1170       |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 2.18e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 41          |
# |    time_elapsed         | 2350        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.032630425 |
# |    clip_fraction        | 0.748       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.147      |
# |    value_loss           | 2.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 42          |
# |    time_elapsed         | 2409        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.032893956 |
# |    clip_fraction        | 0.752       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 914         |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 43          |
# |    time_elapsed         | 2466        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.033178434 |
# |    clip_fraction        | 0.749       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 768         |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 44          |
# |    time_elapsed         | 2522        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.031568777 |
# |    clip_fraction        | 0.735       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 959         |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 45          |
# |    time_elapsed         | 2578        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.032507427 |
# |    clip_fraction        | 0.737       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 763         |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 46          |
# |    time_elapsed         | 2638        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.032385502 |
# |    clip_fraction        | 0.754       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 840         |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.147      |
# |    value_loss           | 2.18e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 180        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 47         |
# |    time_elapsed         | 2694       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.03200523 |
# |    clip_fraction        | 0.744      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.282      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 719        |
# |    n_updates            | 1380       |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 2.16e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 48          |
# |    time_elapsed         | 2750        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.032027666 |
# |    clip_fraction        | 0.739       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 898         |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.23e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 181        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 49         |
# |    time_elapsed         | 2807       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03120527 |
# |    clip_fraction        | 0.729      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.239      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.01e+03   |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 2.26e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 50          |
# |    time_elapsed         | 2863        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.032992803 |
# |    clip_fraction        | 0.749       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 853         |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 2.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 51          |
# |    time_elapsed         | 2918        |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.031540737 |
# |    clip_fraction        | 0.739       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+03    |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 176        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 52         |
# |    time_elapsed         | 2974       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.03182488 |
# |    clip_fraction        | 0.732      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.284      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 923        |
# |    n_updates            | 1530       |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 2.28e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 173       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 53        |
# |    time_elapsed         | 3030      |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 0.0318257 |
# |    clip_fraction        | 0.724     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -111      |
# |    explained_variance   | 0.29      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 837       |
# |    n_updates            | 1560      |
# |    policy_gradient_loss | -0.144    |
# |    value_loss           | 2.05e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 180         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 54          |
# |    time_elapsed         | 3086        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.031516265 |
# |    clip_fraction        | 0.731       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 729         |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 2.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 55          |
# |    time_elapsed         | 3143        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.031818047 |
# |    clip_fraction        | 0.739       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 2.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 56          |
# |    time_elapsed         | 3200        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.031156575 |
# |    clip_fraction        | 0.734       |
# ...
# |    n_updates            | 11160       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.8e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 374         |
# |    time_elapsed         | 50614       |
# |    total_timesteps      | 765952      |
# | train/                  |             |
# |    approx_kl            | 0.039496846 |
# |    clip_fraction        | 0.808       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 735         |
# |    n_updates            | 11190       |
# |    policy_gradient_loss | -0.152      |
# |    value_loss           | 2.48e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 375         |
# |    time_elapsed         | 50657       |
# |    total_timesteps      | 768000      |
# | train/                  |             |
# |    approx_kl            | 0.039486982 |
# |    clip_fraction        | 0.809       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 736         |
# |    n_updates            | 11220       |
# |    policy_gradient_loss | -0.152      |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 376         |
# |    time_elapsed         | 50704       |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.040128507 |
# |    clip_fraction        | 0.8         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 11250       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 377         |
# |    time_elapsed         | 50747       |
# |    total_timesteps      | 772096      |
# | train/                  |             |
# |    approx_kl            | 0.037895344 |
# |    clip_fraction        | 0.8         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 11280       |
# |    policy_gradient_loss | -0.152      |
# |    value_loss           | 2.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 378         |
# |    time_elapsed         | 50789       |
# |    total_timesteps      | 774144      |
# | train/                  |             |
# |    approx_kl            | 0.039249778 |
# |    clip_fraction        | 0.802       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 11310       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 222         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 379         |
# |    time_elapsed         | 50831       |
# |    total_timesteps      | 776192      |
# | train/                  |             |
# |    approx_kl            | 0.039228465 |
# |    clip_fraction        | 0.814       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 11340       |
# |    policy_gradient_loss | -0.153      |
# |    value_loss           | 2.78e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 380        |
# |    time_elapsed         | 50874      |
# |    total_timesteps      | 778240     |
# | train/                  |            |
# |    approx_kl            | 0.03857953 |
# |    clip_fraction        | 0.795      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -109       |
# |    explained_variance   | 0.187      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+03   |
# |    n_updates            | 11370      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.7e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 381         |
# |    time_elapsed         | 50916       |
# |    total_timesteps      | 780288      |
# | train/                  |             |
# |    approx_kl            | 0.038753577 |
# |    clip_fraction        | 0.795       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 11400       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 382         |
# |    time_elapsed         | 50959       |
# |    total_timesteps      | 782336      |
# | train/                  |             |
# |    approx_kl            | 0.039015353 |
# |    clip_fraction        | 0.802       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 931         |
# |    n_updates            | 11430       |
# |    policy_gradient_loss | -0.152      |
# |    value_loss           | 2.67e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 225        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 383        |
# |    time_elapsed         | 51002      |
# |    total_timesteps      | 784384     |
# | train/                  |            |
# |    approx_kl            | 0.03880308 |
# |    clip_fraction        | 0.8        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -109       |
# |    explained_variance   | 0.183      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.25e+03   |
# |    n_updates            | 11460      |
# |    policy_gradient_loss | -0.152     |
# |    value_loss           | 2.64e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 223         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 384         |
# |    time_elapsed         | 51044       |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.037890982 |
# |    clip_fraction        | 0.792       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 908         |
# |    n_updates            | 11490       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 385         |
# |    time_elapsed         | 51086       |
# |    total_timesteps      | 788480      |
# | train/                  |             |
# |    approx_kl            | 0.038995344 |
# |    clip_fraction        | 0.797       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+03    |
# |    n_updates            | 11520       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 386         |
# |    time_elapsed         | 51127       |
# |    total_timesteps      | 790528      |
# | train/                  |             |
# |    approx_kl            | 0.039505333 |
# |    clip_fraction        | 0.803       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 11550       |
# |    policy_gradient_loss | -0.152      |
# |    value_loss           | 2.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 387         |
# |    time_elapsed         | 51169       |
# |    total_timesteps      | 792576      |
# | train/                  |             |
# |    approx_kl            | 0.039034404 |
# |    clip_fraction        | 0.796       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 11580       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.76e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 388        |
# |    time_elapsed         | 51211      |
# |    total_timesteps      | 794624     |
# | train/                  |            |
# |    approx_kl            | 0.03997339 |
# |    clip_fraction        | 0.804      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -109       |
# |    explained_variance   | 0.182      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1e+03      |
# |    n_updates            | 11610      |
# |    policy_gradient_loss | -0.152     |
# |    value_loss           | 2.72e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 389         |
# |    time_elapsed         | 51253       |
# |    total_timesteps      | 796672      |
# | train/                  |             |
# |    approx_kl            | 0.038697436 |
# |    clip_fraction        | 0.797       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 980         |
# |    n_updates            | 11640       |
# |    policy_gradient_loss | -0.152      |
# |    value_loss           | 2.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 390         |
# |    time_elapsed         | 51295       |
# |    total_timesteps      | 798720      |
# | train/                  |             |
# |    approx_kl            | 0.039019138 |
# |    clip_fraction        | 0.8         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 11670       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 223         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 391         |
# |    time_elapsed         | 51337       |
# |    total_timesteps      | 800768      |
# | train/                  |             |
# |    approx_kl            | 0.039239727 |
# |    clip_fraction        | 0.81        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 975         |
# |    n_updates            | 11700       |
# |    policy_gradient_loss | -0.153      |
# |    value_loss           | 2.83e+03    |
# -----------------------------------------
