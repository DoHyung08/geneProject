# %%
from stable_baselines3.common.env_checker import check_env
from geneEnv import geneEnv
from pig import pig
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor

# %%
modelName = "TwoDise"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = geneEnv(2,32,5)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model_add", env=env)
model.learn(total_timesteps=400_000)
model.save("result\\"+modelName+"\\trained_model_add_add")
# Out:
# Gene Environment setting success
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    fps             | 95       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.036207393 |
# |    clip_fraction        | 0.662       |
# ...

# %%
modelName = "TwoDiseInverse"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = geneEnv(2,32,5)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model_add", env=env)
model.learn(total_timesteps=400_000)
model.save("result\\"+modelName+"\\trained_model_add_add")
# Out:
# Gene Environment setting success
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 211      |
# | time/              |          |
# |    fps             | 97       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 2          |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11302924 |
# |    clip_fraction        | 0.843      |
# |    clip_range           | 0.2        |
# ...

# %%
modelName = "MultiAlle"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = geneEnv(1,32,10)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model", env=env)
model.learn(total_timesteps=400_000)
model.save("result\\"+modelName+"\\trained_model_add_add")
# Out:
# Gene Environment setting success
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | 220      |
# | time/              |          |
# |    fps             | 109      |
# |    iterations      | 1        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.038855508 |
# |    clip_fraction        | 0.796       |
# ...

# %%
modelName = "MediFlower2-2"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = ratioEnv(1,32,20)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model", env=env)
model.learn(total_timesteps=800_000)
model.save("result\\"+modelName+"\\trained_model_add")
# Out:
# Gene Environment setting success
