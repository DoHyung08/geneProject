# %%
from stable_baselines3.common.env_checker import check_env
from geneEnv import geneEnv
from pig import pig
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor

# %%
modelName = "TwoDise"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = geneEnv(2,32,5)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model_add", env=env)
model.learn(total_timesteps=400_000)
model.save("result\\"+modelName+"\\trained_model_add_add")
# Out:
# Gene Environment setting success
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    fps             | 95       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.036207393 |
# |    clip_fraction        | 0.662       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 15660       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 3           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.036448553 |
# |    clip_fraction        | 0.662       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 15680       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 4           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.037227042 |
# |    clip_fraction        | 0.658       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 15700       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 5           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.036346875 |
# |    clip_fraction        | 0.656       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+03    |
# |    n_updates            | 15720       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 6           |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.035702795 |
# |    clip_fraction        | 0.654       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+03    |
# |    n_updates            | 15740       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 7           |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.035274923 |
# |    clip_fraction        | 0.643       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 983         |
# |    n_updates            | 15760       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 8           |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.036854915 |
# |    clip_fraction        | 0.661       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 15780       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 9           |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.037056796 |
# |    clip_fraction        | 0.665       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 15800       |
# |    policy_gradient_loss | -0.142      |
# |    value_loss           | 3.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 10          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.035071462 |
# |    clip_fraction        | 0.657       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 15820       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.32e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 11         |
# |    time_elapsed         | 327        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03647866 |
# |    clip_fraction        | 0.657      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.212      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24e+03   |
# |    n_updates            | 15840      |
# |    policy_gradient_loss | -0.14      |
# |    value_loss           | 3.31e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 12          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.035690136 |
# |    clip_fraction        | 0.646       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 15860       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 13          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.035981514 |
# |    clip_fraction        | 0.647       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5e+03     |
# |    n_updates            | 15880       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.41e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 14         |
# |    time_elapsed         | 411        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.03683143 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.237      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4e+03    |
# |    n_updates            | 15900      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.23e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 260        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 15         |
# |    time_elapsed         | 445        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03594254 |
# |    clip_fraction        | 0.66       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.232      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.29e+03   |
# |    n_updates            | 15920      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.29e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 16          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.036185455 |
# |    clip_fraction        | 0.646       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 15940       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 17          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.037088245 |
# |    clip_fraction        | 0.66        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 15960       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 18          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.037487734 |
# |    clip_fraction        | 0.653       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+03    |
# |    n_updates            | 15980       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 19          |
# |    time_elapsed         | 583         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.037026167 |
# |    clip_fraction        | 0.674       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 16000       |
# |    policy_gradient_loss | -0.142      |
# |    value_loss           | 3.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 251        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 20         |
# |    time_elapsed         | 613        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03648591 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.44e+03   |
# |    n_updates            | 16020      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.39e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 21          |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.036694948 |
# |    clip_fraction        | 0.661       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+03    |
# |    n_updates            | 16040       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 22          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.035030253 |
# |    clip_fraction        | 0.646       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+03    |
# |    n_updates            | 16060       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.27e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 250        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 23         |
# |    time_elapsed         | 702        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03541941 |
# |    clip_fraction        | 0.651      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.234      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37e+03   |
# |    n_updates            | 16080      |
# |    policy_gradient_loss | -0.139     |
# |    value_loss           | 3.26e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 24          |
# |    time_elapsed         | 730         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.033636123 |
# |    clip_fraction        | 0.631       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42e+03    |
# |    n_updates            | 16100       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 25          |
# |    time_elapsed         | 757         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.036314644 |
# |    clip_fraction        | 0.654       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 16120       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 26          |
# |    time_elapsed         | 784         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.036048077 |
# |    clip_fraction        | 0.661       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+03    |
# |    n_updates            | 16140       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 27          |
# |    time_elapsed         | 812         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.036489617 |
# |    clip_fraction        | 0.644       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+03    |
# |    n_updates            | 16160       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 28          |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.036062572 |
# |    clip_fraction        | 0.644       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 16180       |
# |    policy_gradient_loss | -0.138      |
# |    value_loss           | 3.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 29          |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.036390718 |
# |    clip_fraction        | 0.651       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+03     |
# |    n_updates            | 16200       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 250        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 30         |
# |    time_elapsed         | 893        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03656839 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.71e+03   |
# |    n_updates            | 16220      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.39e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 31          |
# |    time_elapsed         | 921         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.036421105 |
# |    clip_fraction        | 0.653       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 16240       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 32          |
# |    time_elapsed         | 949         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.035569392 |
# |    clip_fraction        | 0.651       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 16260       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 33          |
# |    time_elapsed         | 976         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.036027092 |
# |    clip_fraction        | 0.65        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 16280       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 256       |
# | time/                   |           |
# |    fps                  | 69        |
# |    iterations           | 34        |
# |    time_elapsed         | 1003      |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0348433 |
# |    clip_fraction        | 0.635     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -107      |
# |    explained_variance   | 0.204     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.52e+03  |
# |    n_updates            | 16300     |
# |    policy_gradient_loss | -0.139    |
# |    value_loss           | 3.44e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 35          |
# |    time_elapsed         | 1031        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.036356837 |
# |    clip_fraction        | 0.66        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+03    |
# |    n_updates            | 16320       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 36          |
# |    time_elapsed         | 1058        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.037506934 |
# |    clip_fraction        | 0.662       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 16340       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 37          |
# |    time_elapsed         | 1085        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.037134096 |
# |    clip_fraction        | 0.646       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+03    |
# |    n_updates            | 16360       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 38          |
# |    time_elapsed         | 1112        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.036202125 |
# |    clip_fraction        | 0.645       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+03    |
# |    n_updates            | 16380       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 251        |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 39         |
# |    time_elapsed         | 1139       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03683482 |
# |    clip_fraction        | 0.655      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.198      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38e+03   |
# |    n_updates            | 16400      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.48e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 264        |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 40         |
# |    time_elapsed         | 1169       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03759555 |
# |    clip_fraction        | 0.652      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.224      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+03   |
# |    n_updates            | 16420      |
# |    policy_gradient_loss | -0.139     |
# |    value_loss           | 3.34e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 41          |
# |    time_elapsed         | 1197        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.035984207 |
# |    clip_fraction        | 0.657       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 16440       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 42          |
# |    time_elapsed         | 1225        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.037727986 |
# |    clip_fraction        | 0.674       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 16460       |
# |    policy_gradient_loss | -0.142      |
# |    value_loss           | 3.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 43          |
# |    time_elapsed         | 1251        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.036313444 |
# |    clip_fraction        | 0.667       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25e+03    |
# |    n_updates            | 16480       |
# |    policy_gradient_loss | -0.142      |
# |    value_loss           | 3.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 44          |
# |    time_elapsed         | 1278        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.036007896 |
# |    clip_fraction        | 0.645       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+03    |
# |    n_updates            | 16500       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 45          |
# |    time_elapsed         | 1305        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.034627564 |
# |    clip_fraction        | 0.651       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 16520       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 46          |
# |    time_elapsed         | 1333        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.036732517 |
# |    clip_fraction        | 0.657       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 16540       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 47          |
# |    time_elapsed         | 1360        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.034909815 |
# |    clip_fraction        | 0.652       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.69e+03    |
# |    n_updates            | 16560       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 48          |
# |    time_elapsed         | 1390        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.036859564 |
# |    clip_fraction        | 0.664       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+03    |
# |    n_updates            | 16580       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.25e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 49         |
# |    time_elapsed         | 1416       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03551271 |
# |    clip_fraction        | 0.652      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.247      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.96e+03   |
# |    n_updates            | 16600      |
# |    policy_gradient_loss | -0.14      |
# |    value_loss           | 3.19e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 50          |
# |    time_elapsed         | 1443        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.036582775 |
# |    clip_fraction        | 0.655       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+03     |
# |    n_updates            | 16620       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.25e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 51          |
# |    time_elapsed         | 1469        |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.036406696 |
# |    clip_fraction        | 0.645       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+03    |
# |    n_updates            | 16640       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 52          |
# |    time_elapsed         | 1496        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.037128054 |
# |    clip_fraction        | 0.665       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 16660       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 53          |
# |    time_elapsed         | 1522        |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.038625076 |
# |    clip_fraction        | 0.679       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 16680       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.44e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 255        |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 54         |
# |    time_elapsed         | 1548       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.03708636 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | 0.212      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77e+03   |
# |    n_updates            | 16700      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.44e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 55          |
# |    time_elapsed         | 1575        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.036149185 |
# |    clip_fraction        | 0.653       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 16720       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# ...
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.21       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.2e+03    |
# |    n_updates            | 19180      |
# |    policy_gradient_loss | -0.138     |
# |    value_loss           | 3.49e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 179         |
# |    time_elapsed         | 4980        |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.039262936 |
# |    clip_fraction        | 0.669       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25e+03    |
# |    n_updates            | 19200       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.47e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 261        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 180        |
# |    time_elapsed         | 5007       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.03793541 |
# |    clip_fraction        | 0.667      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.237      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.76e+03   |
# |    n_updates            | 19220      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.45e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 181         |
# |    time_elapsed         | 5033        |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.040777937 |
# |    clip_fraction        | 0.679       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 19240       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 182        |
# |    time_elapsed         | 5060       |
# |    total_timesteps      | 372736     |
# | train/                  |            |
# |    approx_kl            | 0.04069288 |
# |    clip_fraction        | 0.685      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.24       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.53e+03   |
# |    n_updates            | 19260      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.37e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 259        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 183        |
# |    time_elapsed         | 5086       |
# |    total_timesteps      | 374784     |
# | train/                  |            |
# |    approx_kl            | 0.04186643 |
# |    clip_fraction        | 0.678      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.229      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35e+03   |
# |    n_updates            | 19280      |
# |    policy_gradient_loss | -0.14      |
# |    value_loss           | 3.32e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 184        |
# |    time_elapsed         | 5113       |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.03860193 |
# |    clip_fraction        | 0.671      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.235      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.31e+03   |
# |    n_updates            | 19300      |
# |    policy_gradient_loss | -0.142     |
# |    value_loss           | 3.37e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 185        |
# |    time_elapsed         | 5139       |
# |    total_timesteps      | 378880     |
# | train/                  |            |
# |    approx_kl            | 0.03809406 |
# |    clip_fraction        | 0.668      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.228      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.9e+03    |
# |    n_updates            | 19320      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.39e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 186         |
# |    time_elapsed         | 5165        |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.037582025 |
# |    clip_fraction        | 0.659       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 19340       |
# |    policy_gradient_loss | -0.139      |
# |    value_loss           | 3.42e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 255       |
# | time/                   |           |
# |    fps                  | 73        |
# |    iterations           | 187       |
# |    time_elapsed         | 5192      |
# |    total_timesteps      | 382976    |
# | train/                  |           |
# |    approx_kl            | 0.0389484 |
# |    clip_fraction        | 0.659     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -106      |
# |    explained_variance   | 0.213     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.33e+03  |
# |    n_updates            | 19360     |
# |    policy_gradient_loss | -0.141    |
# |    value_loss           | 3.38e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 188        |
# |    time_elapsed         | 5218       |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.03923486 |
# |    clip_fraction        | 0.678      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.188      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.36e+03   |
# |    n_updates            | 19380      |
# |    policy_gradient_loss | -0.142     |
# |    value_loss           | 3.55e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 189         |
# |    time_elapsed         | 5245        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.037870336 |
# |    clip_fraction        | 0.673       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+03    |
# |    n_updates            | 19400       |
# |    policy_gradient_loss | -0.142      |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 190        |
# |    time_elapsed         | 5271       |
# |    total_timesteps      | 389120     |
# | train/                  |            |
# |    approx_kl            | 0.04081334 |
# |    clip_fraction        | 0.674      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.73e+03   |
# |    n_updates            | 19420      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.33e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 191         |
# |    time_elapsed         | 5297        |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.037769746 |
# |    clip_fraction        | 0.674       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 19440       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 192         |
# |    time_elapsed         | 5325        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.041250847 |
# |    clip_fraction        | 0.671       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+03    |
# |    n_updates            | 19460       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 193         |
# |    time_elapsed         | 5351        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.039128333 |
# |    clip_fraction        | 0.678       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 19480       |
# |    policy_gradient_loss | -0.142      |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 260         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 194         |
# |    time_elapsed         | 5378        |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.037519716 |
# |    clip_fraction        | 0.653       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14e+03    |
# |    n_updates            | 19500       |
# |    policy_gradient_loss | -0.14       |
# |    value_loss           | 3.43e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 195        |
# |    time_elapsed         | 5405       |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.03880143 |
# |    clip_fraction        | 0.663      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.246      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.43e+03   |
# |    n_updates            | 19520      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 3.31e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 196         |
# |    time_elapsed         | 5431        |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.039691336 |
# |    clip_fraction        | 0.675       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 19540       |
# |    policy_gradient_loss | -0.141      |
# |    value_loss           | 3.47e+03    |
# -----------------------------------------

# %%
modelName = "TwoDiseInverse"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = geneEnv(2,32,5)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model_add", env=env)
model.learn(total_timesteps=400_000)
model.save("result\\"+modelName+"\\trained_model_add_add")
# Out:
# Gene Environment setting success
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 211      |
# | time/              |          |
# |    fps             | 97       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 2          |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11302924 |
# |    clip_fraction        | 0.843      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.5      |
# |    explained_variance   | 0.53       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 510        |
# |    n_updates            | 15660      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.39e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 3          |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.10253922 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.4      |
# |    explained_variance   | 0.519      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 535        |
# |    n_updates            | 15680      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 4          |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.10055539 |
# |    clip_fraction        | 0.842      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.6      |
# |    explained_variance   | 0.461      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 810        |
# |    n_updates            | 15700      |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 1.62e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 5           |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.106282786 |
# |    clip_fraction        | 0.841       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93.7       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 494         |
# |    n_updates            | 15720       |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 1.51e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 6          |
# |    time_elapsed         | 174        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.09933952 |
# |    clip_fraction        | 0.835      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.4      |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 619        |
# |    n_updates            | 15740      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 7          |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.10030848 |
# |    clip_fraction        | 0.839      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.3      |
# |    explained_variance   | 0.518      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 644        |
# |    n_updates            | 15760      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 8           |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.102769494 |
# |    clip_fraction        | 0.831       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93.4       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 687         |
# |    n_updates            | 15780       |
# |    policy_gradient_loss | -0.144      |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 9          |
# |    time_elapsed         | 258        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.10563226 |
# |    clip_fraction        | 0.844      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.3      |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 845        |
# |    n_updates            | 15800      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 10         |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.10753901 |
# |    clip_fraction        | 0.843      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.2      |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 541        |
# |    n_updates            | 15820      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 11          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.105025575 |
# |    clip_fraction        | 0.844       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93.4       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 613         |
# |    n_updates            | 15840       |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 1.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 12          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.106937274 |
# |    clip_fraction        | 0.844       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93.1       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 473         |
# |    n_updates            | 15860       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 1.51e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 13         |
# |    time_elapsed         | 384        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.11421022 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.2      |
# |    explained_variance   | 0.515      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 734        |
# |    n_updates            | 15880      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 14          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.117892966 |
# |    clip_fraction        | 0.857       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93.2       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 645         |
# |    n_updates            | 15900       |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 1.32e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 15         |
# |    time_elapsed         | 449        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.10928189 |
# |    clip_fraction        | 0.841      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.2      |
# |    explained_variance   | 0.518      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 510        |
# |    n_updates            | 15920      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 16          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.108914986 |
# |    clip_fraction        | 0.839       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.9       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 641         |
# |    n_updates            | 15940       |
# |    policy_gradient_loss | -0.144      |
# |    value_loss           | 1.56e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 17         |
# |    time_elapsed         | 510        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.10585132 |
# |    clip_fraction        | 0.845      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.1      |
# |    explained_variance   | 0.521      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 717        |
# |    n_updates            | 15960      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 18         |
# |    time_elapsed         | 539        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.12236038 |
# |    clip_fraction        | 0.857      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93        |
# |    explained_variance   | 0.56       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 446        |
# |    n_updates            | 15980      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.36e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 19          |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.117811725 |
# |    clip_fraction        | 0.848       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.8       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 593         |
# |    n_updates            | 16000       |
# |    policy_gradient_loss | -0.144      |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 20         |
# |    time_elapsed         | 600        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.10716463 |
# |    clip_fraction        | 0.837      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.9      |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 962        |
# |    n_updates            | 16020      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 21         |
# |    time_elapsed         | 631        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.10042879 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93        |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 817        |
# |    n_updates            | 16040      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.59e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 22          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.102477096 |
# |    clip_fraction        | 0.829       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.9       |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 923         |
# |    n_updates            | 16060       |
# |    policy_gradient_loss | -0.144      |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 23         |
# |    time_elapsed         | 691        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.10705102 |
# |    clip_fraction        | 0.843      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.7      |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 768        |
# |    n_updates            | 16080      |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 1.4e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 211        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 24         |
# |    time_elapsed         | 721        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.10776427 |
# |    clip_fraction        | 0.841      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93        |
# |    explained_variance   | 0.548      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 629        |
# |    n_updates            | 16100      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.42e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 25          |
# |    time_elapsed         | 752         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.102724545 |
# |    clip_fraction        | 0.836       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.9       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 487         |
# |    n_updates            | 16120       |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 26          |
# |    time_elapsed         | 782         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.113388486 |
# |    clip_fraction        | 0.837       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.8       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 452         |
# |    n_updates            | 16140       |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 1.44e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 27         |
# |    time_elapsed         | 810        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.10663347 |
# |    clip_fraction        | 0.837      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.5      |
# |    explained_variance   | 0.511      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 671        |
# |    n_updates            | 16160      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 28         |
# |    time_elapsed         | 840        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.11079706 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.5      |
# |    explained_variance   | 0.546      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 630        |
# |    n_updates            | 16180      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.35e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 223         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 29          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.101150624 |
# |    clip_fraction        | 0.837       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.3       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 663         |
# |    n_updates            | 16200       |
# |    policy_gradient_loss | -0.145      |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 30         |
# |    time_elapsed         | 902        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.10875691 |
# |    clip_fraction        | 0.85       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.2      |
# |    explained_variance   | 0.552      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 596        |
# |    n_updates            | 16220      |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 1.4e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 31         |
# |    time_elapsed         | 932        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.10288377 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.3      |
# |    explained_variance   | 0.536      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 775        |
# |    n_updates            | 16240      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 32         |
# |    time_elapsed         | 963        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.10818154 |
# |    clip_fraction        | 0.827      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.3      |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 547        |
# |    n_updates            | 16260      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 33          |
# |    time_elapsed         | 994         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.104745686 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.1       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 678         |
# |    n_updates            | 16280       |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 34         |
# |    time_elapsed         | 1022       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.10429557 |
# |    clip_fraction        | 0.837      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.5      |
# |    explained_variance   | 0.528      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 569        |
# |    n_updates            | 16300      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.45e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 228        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 35         |
# |    time_elapsed         | 1050       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.11387818 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.2      |
# |    explained_variance   | 0.543      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 754        |
# |    n_updates            | 16320      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.34e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 36         |
# |    time_elapsed         | 1078       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.11307591 |
# |    clip_fraction        | 0.849      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.5      |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 750        |
# |    n_updates            | 16340      |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 37         |
# |    time_elapsed         | 1109       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.10192885 |
# |    clip_fraction        | 0.836      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.1      |
# |    explained_variance   | 0.51       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 953        |
# |    n_updates            | 16360      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.54e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 38         |
# |    time_elapsed         | 1139       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.11643638 |
# |    clip_fraction        | 0.832      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.3      |
# |    explained_variance   | 0.521      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 739        |
# |    n_updates            | 16380      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.42e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 39         |
# |    time_elapsed         | 1169       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.11808413 |
# |    clip_fraction        | 0.853      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.2      |
# |    explained_variance   | 0.56       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 757        |
# |    n_updates            | 16400      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.36e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 211        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 40         |
# |    time_elapsed         | 1200       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.10001652 |
# |    clip_fraction        | 0.828      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.1      |
# |    explained_variance   | 0.503      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 665        |
# |    n_updates            | 16420      |
# |    policy_gradient_loss | -0.142     |
# |    value_loss           | 1.51e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 41         |
# |    time_elapsed         | 1231       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.11115667 |
# |    clip_fraction        | 0.834      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.2      |
# |    explained_variance   | 0.49       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 640        |
# |    n_updates            | 16440      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.53e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 42          |
# |    time_elapsed         | 1261        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.116879135 |
# |    clip_fraction        | 0.846       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92         |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 684         |
# |    n_updates            | 16460       |
# |    policy_gradient_loss | -0.146      |
# |    value_loss           | 1.39e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 43         |
# |    time_elapsed         | 1294       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.10566813 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.9      |
# |    explained_variance   | 0.539      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 738        |
# |    n_updates            | 16480      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.48e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 44         |
# |    time_elapsed         | 1326       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.10358401 |
# |    clip_fraction        | 0.835      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.9      |
# |    explained_variance   | 0.522      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 750        |
# |    n_updates            | 16500      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.51e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 226        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 45         |
# |    time_elapsed         | 1359       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.10129921 |
# |    clip_fraction        | 0.836      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92        |
# |    explained_variance   | 0.548      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 663        |
# |    n_updates            | 16520      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.42e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 46         |
# |    time_elapsed         | 1388       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.10094271 |
# |    clip_fraction        | 0.829      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.7      |
# |    explained_variance   | 0.546      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 602        |
# |    n_updates            | 16540      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 47         |
# |    time_elapsed         | 1416       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.10099846 |
# |    clip_fraction        | 0.828      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.6      |
# |    explained_variance   | 0.531      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 552        |
# |    n_updates            | 16560      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 215       |
# | time/                   |           |
# |    fps                  | 68        |
# |    iterations           | 48        |
# |    time_elapsed         | 1445      |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.1015424 |
# |    clip_fraction        | 0.838     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -91.7     |
# |    explained_variance   | 0.509     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 652       |
# |    n_updates            | 16580     |
# |    policy_gradient_loss | -0.144    |
# |    value_loss           | 1.56e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 49         |
# |    time_elapsed         | 1476       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.10035124 |
# |    clip_fraction        | 0.837      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.8      |
# |    explained_variance   | 0.517      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 511        |
# |    n_updates            | 16600      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.53e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 50         |
# |    time_elapsed         | 1506       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.10234226 |
# |    clip_fraction        | 0.839      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.8      |
# |    explained_variance   | 0.518      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 828        |
# |    n_updates            | 16620      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 226        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 51         |
# |    time_elapsed         | 1538       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.10542312 |
# |    clip_fraction        | 0.838      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92        |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 616        |
# |    n_updates            | 16640      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 227        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 52         |
# |    time_elapsed         | 1568       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.10279944 |
# |    clip_fraction        | 0.83       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.7      |
# |    explained_variance   | 0.556      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 597        |
# |    n_updates            | 16660      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.45e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 211        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 53         |
# |    time_elapsed         | 1598       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.10023803 |
# |    clip_fraction        | 0.838      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.7      |
# |    explained_variance   | 0.542      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 708        |
# |    n_updates            | 16680      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.48e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 224        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 54         |
# |    time_elapsed         | 1629       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.10520738 |
# |    clip_fraction        | 0.831      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.7      |
# |    explained_variance   | 0.544      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 585        |
# |    n_updates            | 16700      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.46e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 228        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 55         |
# |    time_elapsed         | 1657       |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.10206445 |
# |    clip_fraction        | 0.847      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.5      |
# |    explained_variance   | 0.547      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 562        |
# |    n_updates            | 16720      |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 224        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 56         |
# |    time_elapsed         | 1685       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.10343106 |
# |    clip_fraction        | 0.846      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.4      |
# |    explained_variance   | 0.527      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 579        |
# |    n_updates            | 16740      |
# |    policy_gradient_loss | -0.146     |
# |    value_loss           | 1.52e+03   |
# ...
# |    approx_kl            | 0.11114858 |
# |    clip_fraction        | 0.838      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.5      |
# |    explained_variance   | 0.601      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 560        |
# |    n_updates            | 19180      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.38e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 231        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 179        |
# |    time_elapsed         | 5459       |
# |    total_timesteps      | 366592     |
# | train/                  |            |
# |    approx_kl            | 0.10767791 |
# |    clip_fraction        | 0.83       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.5      |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 630        |
# |    n_updates            | 19200      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 1.45e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 230        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 180        |
# |    time_elapsed         | 5492       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.10622056 |
# |    clip_fraction        | 0.832      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.3      |
# |    explained_variance   | 0.552      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 642        |
# |    n_updates            | 19220      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 1.53e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 230        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 181        |
# |    time_elapsed         | 5527       |
# |    total_timesteps      | 370688     |
# | train/                  |            |
# |    approx_kl            | 0.11188179 |
# |    clip_fraction        | 0.839      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.4      |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 712        |
# |    n_updates            | 19240      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.42e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 232        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 182        |
# |    time_elapsed         | 5558       |
# |    total_timesteps      | 372736     |
# | train/                  |            |
# |    approx_kl            | 0.12261403 |
# |    clip_fraction        | 0.846      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.5      |
# |    explained_variance   | 0.586      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 717        |
# |    n_updates            | 19260      |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 1.42e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 230        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 183        |
# |    time_elapsed         | 5588       |
# |    total_timesteps      | 374784     |
# | train/                  |            |
# |    approx_kl            | 0.11788745 |
# |    clip_fraction        | 0.834      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.7      |
# |    explained_variance   | 0.595      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 593        |
# |    n_updates            | 19280      |
# |    policy_gradient_loss | -0.14      |
# |    value_loss           | 1.45e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 228        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 184        |
# |    time_elapsed         | 5618       |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.10793856 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.4      |
# |    explained_variance   | 0.581      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 435        |
# |    n_updates            | 19300      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 232        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 185        |
# |    time_elapsed         | 5647       |
# |    total_timesteps      | 378880     |
# | train/                  |            |
# |    approx_kl            | 0.11038935 |
# |    clip_fraction        | 0.842      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.3      |
# |    explained_variance   | 0.569      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 717        |
# |    n_updates            | 19320      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.53e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 229        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 186        |
# |    time_elapsed         | 5677       |
# |    total_timesteps      | 380928     |
# | train/                  |            |
# |    approx_kl            | 0.10683697 |
# |    clip_fraction        | 0.834      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.5      |
# |    explained_variance   | 0.585      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 731        |
# |    n_updates            | 19340      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 235        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 187        |
# |    time_elapsed         | 5706       |
# |    total_timesteps      | 382976     |
# | train/                  |            |
# |    approx_kl            | 0.11103043 |
# |    clip_fraction        | 0.829      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.6      |
# |    explained_variance   | 0.594      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 532        |
# |    n_updates            | 19360      |
# |    policy_gradient_loss | -0.142     |
# |    value_loss           | 1.43e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 230        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 188        |
# |    time_elapsed         | 5735       |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.12898245 |
# |    clip_fraction        | 0.835      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.5      |
# |    explained_variance   | 0.599      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 599        |
# |    n_updates            | 19380      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.4e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 231        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 189        |
# |    time_elapsed         | 5766       |
# |    total_timesteps      | 387072     |
# | train/                  |            |
# |    approx_kl            | 0.11587113 |
# |    clip_fraction        | 0.837      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.2      |
# |    explained_variance   | 0.574      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 569        |
# |    n_updates            | 19400      |
# |    policy_gradient_loss | -0.141     |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 235        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 190        |
# |    time_elapsed         | 5797       |
# |    total_timesteps      | 389120     |
# | train/                  |            |
# |    approx_kl            | 0.11333716 |
# |    clip_fraction        | 0.834      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.2      |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 602        |
# |    n_updates            | 19420      |
# |    policy_gradient_loss | -0.144     |
# |    value_loss           | 1.43e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 231        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 191        |
# |    time_elapsed         | 5829       |
# |    total_timesteps      | 391168     |
# | train/                  |            |
# |    approx_kl            | 0.12059783 |
# |    clip_fraction        | 0.842      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.5      |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 546        |
# |    n_updates            | 19440      |
# |    policy_gradient_loss | -0.145     |
# |    value_loss           | 1.39e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 233        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 192        |
# |    time_elapsed         | 5859       |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.11363525 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.1      |
# |    explained_variance   | 0.607      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 803        |
# |    n_updates            | 19460      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.41e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 193         |
# |    time_elapsed         | 5890        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.114291176 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -87.2       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 416         |
# |    n_updates            | 19480       |
# |    policy_gradient_loss | -0.144      |
# |    value_loss           | 1.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 194         |
# |    time_elapsed         | 5921        |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.105929606 |
# |    clip_fraction        | 0.843       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -87.3       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 813         |
# |    n_updates            | 19500       |
# |    policy_gradient_loss | -0.143      |
# |    value_loss           | 1.37e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 231        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 195        |
# |    time_elapsed         | 5952       |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.11160785 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87        |
# |    explained_variance   | 0.601      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 673        |
# |    n_updates            | 19520      |
# |    policy_gradient_loss | -0.142     |
# |    value_loss           | 1.38e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 224        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 196        |
# |    time_elapsed         | 5986       |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.11359258 |
# |    clip_fraction        | 0.841      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87        |
# |    explained_variance   | 0.607      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 856        |
# |    n_updates            | 19540      |
# |    policy_gradient_loss | -0.143     |
# |    value_loss           | 1.33e+03   |
# ----------------------------------------

# %%
modelName = "MultiAlle"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = geneEnv(1,32,10)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model_add", env=env)
model.learn(total_timesteps=400_000)
model.save("result\\"+modelName+"\\trained_model_add_add")
# Out:
# Gene Environment setting success
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    fps             | 71       |
# |    iterations      | 1        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 2           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.054164935 |
# |    clip_fraction        | 0.836       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 978         |
# |    n_updates            | 23490       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 3           |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.056360886 |
# |    clip_fraction        | 0.839       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 864         |
# |    n_updates            | 23520       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 250        |
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 4          |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.05582726 |
# |    clip_fraction        | 0.838      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 886        |
# |    n_updates            | 23550      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.4e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 247        |
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 5          |
# |    time_elapsed         | 189        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.05358065 |
# |    clip_fraction        | 0.836      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.347      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 984        |
# |    n_updates            | 23580      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.63e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 6          |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.05617607 |
# |    clip_fraction        | 0.842      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.402      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+03   |
# |    n_updates            | 23610      |
# |    policy_gradient_loss | -0.152     |
# |    value_loss           | 2.34e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 7           |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.053080574 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 947         |
# |    n_updates            | 23640       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 8           |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.057745688 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 773         |
# |    n_updates            | 23670       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 9           |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.055554584 |
# |    clip_fraction        | 0.841       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 23700       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 10          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.054271456 |
# |    clip_fraction        | 0.844       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 857         |
# |    n_updates            | 23730       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.48e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 11         |
# |    time_elapsed         | 387        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.05690677 |
# |    clip_fraction        | 0.838      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.409      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 990        |
# |    n_updates            | 23760      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.24e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 254        |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 12         |
# |    time_elapsed         | 419        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.05666281 |
# |    clip_fraction        | 0.834      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.374      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06e+03   |
# |    n_updates            | 23790      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 13          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.058546335 |
# |    clip_fraction        | 0.835       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+03    |
# |    n_updates            | 23820       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 14          |
# |    time_elapsed         | 485         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.055229537 |
# |    clip_fraction        | 0.844       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+03    |
# |    n_updates            | 23850       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 15          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.052376084 |
# |    clip_fraction        | 0.837       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 23880       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 16          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.054105178 |
# |    clip_fraction        | 0.831       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 970         |
# |    n_updates            | 23910       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 248        |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 17         |
# |    time_elapsed         | 585        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.05321904 |
# |    clip_fraction        | 0.839      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.335      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 965        |
# |    n_updates            | 23940      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.65e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 18         |
# |    time_elapsed         | 617        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.05406644 |
# |    clip_fraction        | 0.837      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.345      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12e+03   |
# |    n_updates            | 23970      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.6e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 19          |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.056315172 |
# |    clip_fraction        | 0.843       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 24000       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 257       |
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 20        |
# |    time_elapsed         | 682       |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0505162 |
# |    clip_fraction        | 0.819     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -106      |
# |    explained_variance   | 0.325     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 941       |
# |    n_updates            | 24030     |
# |    policy_gradient_loss | -0.147    |
# |    value_loss           | 2.67e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 21          |
# |    time_elapsed         | 714         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.052882977 |
# |    clip_fraction        | 0.819       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 994         |
# |    n_updates            | 24060       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.7e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 22         |
# |    time_elapsed         | 747        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.05464844 |
# |    clip_fraction        | 0.834      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.376      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.04e+03   |
# |    n_updates            | 24090      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.47e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 23          |
# |    time_elapsed         | 779         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.054564282 |
# |    clip_fraction        | 0.826       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 24120       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.58e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 24         |
# |    time_elapsed         | 811        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.05662449 |
# |    clip_fraction        | 0.854      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.408      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 635        |
# |    n_updates            | 24150      |
# |    policy_gradient_loss | -0.152     |
# |    value_loss           | 2.25e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 25          |
# |    time_elapsed         | 845         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.054005798 |
# |    clip_fraction        | 0.827       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 24180       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 26         |
# |    time_elapsed         | 881        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.05541639 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.42       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.49e+03   |
# |    n_updates            | 24210      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.29e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 27          |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.052031435 |
# |    clip_fraction        | 0.829       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 963         |
# |    n_updates            | 24240       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.42e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 255        |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 28         |
# |    time_elapsed         | 945        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.05453963 |
# |    clip_fraction        | 0.836      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.355      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17e+03   |
# |    n_updates            | 24270      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.51e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 29          |
# |    time_elapsed         | 976         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.052972756 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 24300       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 30          |
# |    time_elapsed         | 1007        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.054853518 |
# |    clip_fraction        | 0.831       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 24330       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 31          |
# |    time_elapsed         | 1039        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.054651447 |
# |    clip_fraction        | 0.839       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 858         |
# |    n_updates            | 24360       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 32          |
# |    time_elapsed         | 1070        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.056078717 |
# |    clip_fraction        | 0.835       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 834         |
# |    n_updates            | 24390       |
# |    policy_gradient_loss | -0.151      |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 250        |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 33         |
# |    time_elapsed         | 1101       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.05459681 |
# |    clip_fraction        | 0.827      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.414      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 836        |
# |    n_updates            | 24420      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.35e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 255        |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 34         |
# |    time_elapsed         | 1133       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.05352864 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 758        |
# |    n_updates            | 24450      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.46e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 35          |
# |    time_elapsed         | 1164        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.054662623 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+03    |
# |    n_updates            | 24480       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 36          |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.053828638 |
# |    clip_fraction        | 0.833       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 919         |
# |    n_updates            | 24510       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 37          |
# |    time_elapsed         | 1227        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.052131087 |
# |    clip_fraction        | 0.822       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 24540       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.73e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 38         |
# |    time_elapsed         | 1258       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.05433078 |
# |    clip_fraction        | 0.843      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.388      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14e+03   |
# |    n_updates            | 24570      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.38e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 39         |
# |    time_elapsed         | 1290       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.05645684 |
# |    clip_fraction        | 0.839      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.446      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 743        |
# |    n_updates            | 24600      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.14e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 40          |
# |    time_elapsed         | 1321        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.056574214 |
# |    clip_fraction        | 0.833       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+03    |
# |    n_updates            | 24630       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 41          |
# |    time_elapsed         | 1352        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.055406906 |
# |    clip_fraction        | 0.834       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+03    |
# |    n_updates            | 24660       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 42         |
# |    time_elapsed         | 1385       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.05537646 |
# |    clip_fraction        | 0.842      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.39       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15e+03   |
# |    n_updates            | 24690      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.42e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 43          |
# |    time_elapsed         | 1417        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.057434127 |
# |    clip_fraction        | 0.834       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 888         |
# |    n_updates            | 24720       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 44          |
# |    time_elapsed         | 1448        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.058925044 |
# |    clip_fraction        | 0.845       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 795         |
# |    n_updates            | 24750       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 45          |
# |    time_elapsed         | 1480        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.055900816 |
# |    clip_fraction        | 0.836       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 24780       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.52e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 46         |
# |    time_elapsed         | 1512       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.05589413 |
# |    clip_fraction        | 0.833      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.389      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.28e+03   |
# |    n_updates            | 24810      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.44e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 47          |
# |    time_elapsed         | 1543        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.055663843 |
# |    clip_fraction        | 0.837       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 24840       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 48         |
# |    time_elapsed         | 1574       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.05309291 |
# |    clip_fraction        | 0.839      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.38       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 954        |
# |    n_updates            | 24870      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.45e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 49          |
# |    time_elapsed         | 1605        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.059442446 |
# |    clip_fraction        | 0.838       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 835         |
# |    n_updates            | 24900       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 260         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 50          |
# |    time_elapsed         | 1637        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.056586806 |
# |    clip_fraction        | 0.84        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 24930       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 250       |
# | time/                   |           |
# |    fps                  | 62        |
# |    iterations           | 51        |
# |    time_elapsed         | 1668      |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.0617285 |
# |    clip_fraction        | 0.844     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -106      |
# |    explained_variance   | 0.442     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.26e+03  |
# |    n_updates            | 24960     |
# |    policy_gradient_loss | -0.15     |
# |    value_loss           | 2.2e+03   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 255        |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 52         |
# |    time_elapsed         | 1700       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.05596655 |
# |    clip_fraction        | 0.835      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0.354      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 727        |
# |    n_updates            | 24990      |
# |    policy_gradient_loss | -0.148     |
# |    value_loss           | 2.51e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 53          |
# |    time_elapsed         | 1732        |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.056072384 |
# |    clip_fraction        | 0.837       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 25020       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 54          |
# |    time_elapsed         | 1764        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.054952838 |
# |    clip_fraction        | 0.84        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 869         |
# |    n_updates            | 25050       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 55          |
# |    time_elapsed         | 1795        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.058335148 |
# |    clip_fraction        | 0.846       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 25080       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 56         |
# |    time_elapsed         | 1827       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# ...
# |    clip_fraction        | 0.846       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -104        |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+03    |
# |    n_updates            | 28770       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 179         |
# |    time_elapsed         | 5726        |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.066423096 |
# |    clip_fraction        | 0.847       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -104        |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+03    |
# |    n_updates            | 28800       |
# |    policy_gradient_loss | -0.15       |
# |    value_loss           | 2.53e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 180        |
# |    time_elapsed         | 5758       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.06716654 |
# |    clip_fraction        | 0.857      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.446      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24e+03   |
# |    n_updates            | 28830      |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 2.32e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 265        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 181        |
# |    time_elapsed         | 5790       |
# |    total_timesteps      | 370688     |
# | train/                  |            |
# |    approx_kl            | 0.06677287 |
# |    clip_fraction        | 0.857      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.468      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 866        |
# |    n_updates            | 28860      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.22e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 182        |
# |    time_elapsed         | 5822       |
# |    total_timesteps      | 372736     |
# | train/                  |            |
# |    approx_kl            | 0.06841516 |
# |    clip_fraction        | 0.853      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.471      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06e+03   |
# |    n_updates            | 28890      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.23e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 183        |
# |    time_elapsed         | 5854       |
# |    total_timesteps      | 374784     |
# | train/                  |            |
# |    approx_kl            | 0.06593566 |
# |    clip_fraction        | 0.847      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.445      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+03   |
# |    n_updates            | 28920      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.38e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 184         |
# |    time_elapsed         | 5885        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.063469075 |
# |    clip_fraction        | 0.84        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -104        |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 846         |
# |    n_updates            | 28950       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 261      |
# | time/                   |          |
# |    fps                  | 64       |
# |    iterations           | 185      |
# |    time_elapsed         | 5917     |
# |    total_timesteps      | 378880   |
# | train/                  |          |
# |    approx_kl            | 0.065795 |
# |    clip_fraction        | 0.843    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -104     |
# |    explained_variance   | 0.433    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.16e+03 |
# |    n_updates            | 28980    |
# |    policy_gradient_loss | -0.147   |
# |    value_loss           | 2.34e+03 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 261        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 186        |
# |    time_elapsed         | 5949       |
# |    total_timesteps      | 380928     |
# | train/                  |            |
# |    approx_kl            | 0.06345482 |
# |    clip_fraction        | 0.844      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.437      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13e+03   |
# |    n_updates            | 29010      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.38e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 187         |
# |    time_elapsed         | 5981        |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.063873366 |
# |    clip_fraction        | 0.847       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -104        |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 892         |
# |    n_updates            | 29040       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 258       |
# | time/                   |           |
# |    fps                  | 64        |
# |    iterations           | 188       |
# |    time_elapsed         | 6013      |
# |    total_timesteps      | 385024    |
# | train/                  |           |
# |    approx_kl            | 0.0684022 |
# |    clip_fraction        | 0.852     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -104      |
# |    explained_variance   | 0.489     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.13e+03  |
# |    n_updates            | 29070     |
# |    policy_gradient_loss | -0.149    |
# |    value_loss           | 2.24e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 260        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 189        |
# |    time_elapsed         | 6045       |
# |    total_timesteps      | 387072     |
# | train/                  |            |
# |    approx_kl            | 0.06308794 |
# |    clip_fraction        | 0.844      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.404      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22e+03   |
# |    n_updates            | 29100      |
# |    policy_gradient_loss | -0.148     |
# |    value_loss           | 2.59e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 190         |
# |    time_elapsed         | 6077        |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.063641205 |
# |    clip_fraction        | 0.84        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -104        |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 29130       |
# |    policy_gradient_loss | -0.149      |
# |    value_loss           | 2.57e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 191        |
# |    time_elapsed         | 6108       |
# |    total_timesteps      | 391168     |
# | train/                  |            |
# |    approx_kl            | 0.06964731 |
# |    clip_fraction        | 0.856      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.442      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 914        |
# |    n_updates            | 29160      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.41e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 192        |
# |    time_elapsed         | 6140       |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.06472375 |
# |    clip_fraction        | 0.85       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 764        |
# |    n_updates            | 29190      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.32e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 263         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 193         |
# |    time_elapsed         | 6172        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.068058126 |
# |    clip_fraction        | 0.848       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -104        |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 29220       |
# |    policy_gradient_loss | -0.148      |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 194        |
# |    time_elapsed         | 6204       |
# |    total_timesteps      | 397312     |
# | train/                  |            |
# |    approx_kl            | 0.06846265 |
# |    clip_fraction        | 0.848      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.438      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 923        |
# |    n_updates            | 29250      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.37e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 255        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 195        |
# |    time_elapsed         | 6236       |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.06629691 |
# |    clip_fraction        | 0.85       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.439      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 983        |
# |    n_updates            | 29280      |
# |    policy_gradient_loss | -0.15      |
# |    value_loss           | 2.42e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 260        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 196        |
# |    time_elapsed         | 6267       |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.06862795 |
# |    clip_fraction        | 0.845      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -104       |
# |    explained_variance   | 0.45       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 839        |
# |    n_updates            | 29310      |
# |    policy_gradient_loss | -0.149     |
# |    value_loss           | 2.3e+03    |
# ----------------------------------------

# %%
modelName = "MediFlower2-2"


with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
exec(code)


env = ratioEnv(1,32,20)
check_env(env)


env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

model = PPO.load("result\\"+modelName+"\\trained_model", env=env)
model.learn(total_timesteps=800_000)
model.save("result\\"+modelName+"\\trained_model_add")
# Out:
# Gene Environment setting success
