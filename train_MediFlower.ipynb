# %% [markdown]
# ### train

# %%
modelName = "MediFlower2"

# %%
from stable_baselines3.common.env_checker import check_env
from geneEnv import geneEnv
from ratioEnv import ratioEnv
from flockEnv import flockEnv
from pig import pig



with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
# 읽어온 코드 실행
exec(code)


env = ratioEnv(1,32,20)
# It will check your custom environment and output additional warnings if needed
check_env(env)
# Out:
# Gene Environment setting success

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor
from geneEnv import geneEnv



env = ratioEnv(1,32,20)
env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

# print(f"Observation space: {env.observation_space}")
# print(f"Action space: {env.action_space}")
# print(f"Sample observation: {env.reset()}")

model = PPO("MlpPolicy", env, verbose=1,n_epochs=30)
model.learn(total_timesteps=1600_000)
model.save("result\\"+modelName+"\\trained_model")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -419     |
# | time/              |          |
# |    fps             | 96       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -502         |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 2            |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0031957654 |
# |    clip_fraction        | 0.0144       |
# ...

# %% [markdown]
# # train 2

# %%
modelName = "MediFlower2-2"

# %%
from stable_baselines3.common.env_checker import check_env
from geneEnv import geneEnv
from ratioEnv import ratioEnv
from flockEnv import flockEnv
from pig import pig



with open("result\\"+modelName+"\\pigInfo.txt", "r") as f:
    code = f.read()
# 읽어온 코드 실행
exec(code)


env = ratioEnv(1,32,20)
# It will check your custom environment and output additional warnings if needed
check_env(env)
# Out:
# Gene Environment setting success

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor
from geneEnv import geneEnv



env = ratioEnv(1,32,20)
env = Monitor(env, filename="result\\"+modelName+"\\monitor.csv")

# print(f"Observation space: {env.observation_space}")
# print(f"Action space: {env.action_space}")
# print(f"Sample observation: {env.reset()}")

model = PPO("MlpPolicy", env, verbose=1,n_epochs=20)
model.learn(total_timesteps=800_000)
model.save("result\\"+modelName+"\\trained_model")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 20        |
# |    ep_rew_mean     | -1.09e+04 |
# | time/              |           |
# |    fps             | 76        |
# |    iterations      | 1         |
# |    time_elapsed    | 26        |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | -1.02e+04   |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 2           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.003427133 |
# |    clip_fraction        | 0.00339     |
# |    clip_range           | 0.2         |
# ...
